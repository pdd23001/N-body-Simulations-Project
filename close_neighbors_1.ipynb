# %% [markdown]
# **Imports**

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_aer import AerSimulator

from oracles_grover import marked_oracle

import numpy as np
import random
import math

from grover import Grover_Algorithm

# %% [markdown]
# **Parameter Tuning**

# %% [markdown]
# Manual Input

# %%
n=10
m_initial = 2
lambda_val=6/5
desired_success_rate=0.99

# %% [markdown]
# Calculated Params i.e dependent on manual params

# %%
N=n*(n-1)/2 
alpha=-math.log(1-desired_success_rate)/math.log(n) #Can use n or N
k=int(450*alpha*math.log(n)) 
num_qubits=math.ceil(math.log2(N))

# %%
print("N =", N)
print("Alpha =",alpha)
print("k =",k)
print("num_qubits =", num_qubits)
# Out:
# N = 45.0
# Alpha = 1.9999999999999996
# k = 2072
# num_qubits = 6

# %% [markdown]
# **Marked States for Current Fake Oracle**

# %%
def random_bitstrings(num_bits: int, num_count: int):
    """Generate num_count unique random bitstrings of length num_bits."""
    if num_count > 2**num_bits:
        raise ValueError("Cannot generate more unique bitstrings than possible combinations.")

    seen = set()
    while len(seen) < num_count:
        bitstring = ''.join(random.choice('01') for _ in range(num_bits))
        seen.add(bitstring)
    return seen

# %%
marked_states= random_bitstrings(num_qubits,10)
print(marked_states)
# Out:
# {'110100', '010000', '101111', '011011', '011101', '111011', '000010', '011001', '001001', '111101'}

# %% [markdown]
# **Algorithm Elements**

# %%
oracle=marked_oracle(marked_states, num_qubits=num_qubits)
backend= AerSimulator()

# %%
grover=Grover_Algorithm(oracle=oracle, backend=backend, optimization_level=0)

# %% [markdown]
# **First Stage**

# %%
m=m_initial
while True:
    n_success=0
    for i in range(k):
        j=random.randint(0,math.ceil(m)-1) #isn't it 0<j<m? and not 0<=j<m? what happens when m=1??
        qc=grover.create_grover_circuit(iterations=j)
        print(id(grover.oracle))
        result=grover.run(qc)
        if result in marked_states:
            n_success+=1
    if n_success/k>=0.2:
        break
    m=min(lambda_val*m,int(math.sqrt(N)))
# Out:
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# 5016644176
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/inspect.py:3255, in Signature._bind(self, args, kwargs, partial)
#    3254 try:
# -> 3255     arg_val = kwargs.pop(param_name)
#    3256 except KeyError:
#    3257     # We have no value for this parameter.  It's fine though,
#    3258     # if it has a default value, or it is an '*args'-like
#    3259     # parameter, left alone by the processing of positional
#    3260     # arguments.
#
# KeyError: 'min_qubits'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 6
#       4 for i in range(k):
#       5     j=random.randint(0,math.ceil(m)-1) #isn't it 0<j<m? and not 0<=j<m? what happens when m=1??
# ----> 6     qc=grover.create_grover_circuit(iterations=j)
#       7     print(id(grover.oracle))
#       8     result=grover.run(qc)
#
# File ~/Downloads/N-Body Simulations Project/Code/grover.py:32, in Grover_Algorithm.create_grover_circuit(self, iterations)
#      30 qc.measure_all()
#      31 if self.backend:
# ---> 32     qc=self.pm.run(qc)
#      33 return qc
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passmanager.py:459, in StagedPassManager.run(self, circuits, output_name, callback, num_processes, property_set)
#     449 def run(
#     450     self,
#     451     circuits: _CircuitsT,
#    (...)    456     property_set: dict[str, object] | None = None,
#     457 ) -> _CircuitsT:
#     458     self._update_passmanager()
# --> 459     return super().run(circuits, output_name, callback, num_processes=num_processes)
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passmanager.py:482, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     479 @wraps(meth)
#     480 def wrapper(*meth_args, **meth_kwargs):
#     481     try:
# --> 482         return meth(*meth_args, **meth_kwargs)
#     483     except TranspilerError:
#     484         # If it's already a `TranspilerError` subclass, don't erase the extra information.
#     485         raise
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passmanager.py:241, in PassManager.run(self, circuits, output_name, callback, num_processes, property_set)
#     238 if callback is not None:
#     239     callback = _legacy_style_callback(callback)
# --> 241 return super().run(
#     242     in_programs=circuits,
#     243     callback=callback,
#     244     output_name=output_name,
#     245     num_processes=num_processes,
#     246     property_set=property_set,
#     247 )
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/passmanager/passmanager.py:238, in BasePassManager.run(self, in_programs, callback, num_processes, property_set, **kwargs)
#     234 # If we're not going to run in parallel, we want to avoid spending time `dill` serializing
#     235 # ourselves, since that can be quite expensive.
#     236 if len(in_programs) == 1 or not should_run_in_parallel(num_processes):
#     237     out = [
# --> 238         _run_workflow(
#     239             program=program,
#     240             pass_manager=self,
#     241             callback=callback,
#     242             initial_property_set=property_set,
#     243             **kwargs,
#     244         )
#     245         for program in in_programs
#     246     ]
#     247     if len(in_programs) == 1 and not is_list:
#     248         return out[0]
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/passmanager/passmanager.py:310, in _run_workflow(program, pass_manager, initial_property_set, **kwargs)
#     303 passmanager_ir = pass_manager._passmanager_frontend(
#     304     input_program=program,
#     305     **kwargs,
#     306 )
#     307 property_set = (
#     308     PropertySet() if initial_property_set is None else PropertySet(initial_property_set)
#     309 )
# --> 310 passmanager_ir, final_state = flow_controller.execute(
#     311     passmanager_ir=passmanager_ir,
#     312     state=PassManagerState(workflow_status=initial_status, property_set=property_set),
#     313     callback=kwargs.get("callback", None),
#     314 )
#     315 # The `property_set` has historically been returned as a mutable attribute on `PassManager`
#     316 # This makes us non-reentrant (though `PassManager` would be dependent on its internal tasks to
#     317 # be re-entrant if that was required), but is consistent with previous interfaces.  We're still
#     318 # safe to be called in a serial loop, again assuming internal tasks are re-runnable.  The
#     319 # conversion to the backend language is also allowed to use the property set, so it must be set
#     320 # before calling it.
#     321 pass_manager.property_set = final_state.property_set
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/basepasses.py:167, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     161 def execute(
#     162     self,
#     163     passmanager_ir: PassManagerIR,
#     164     state: PassManagerState,
#     165     callback: Callable = None,
#     166 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 167     new_dag, state = super().execute(
#     168         passmanager_ir=passmanager_ir,
#     169         state=state,
#     170         callback=callback,
#     171     )
#     173     if state.workflow_status.previous_run == RunState.SUCCESS:
#     174         if not isinstance(new_dag, DAGCircuit):
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:277, in HighLevelSynthesis.run(self, dag)
#     264 def run(self, dag: DAGCircuit) -> DAGCircuit:
#     265     """Run the HighLevelSynthesis pass on `dag`.
#     266
#     267     Args:
#    (...)    275         (for instance, when the specified synthesis method is not available).
#     276     """
# --> 277     res = run_on_dag(dag, self.data, self.qubits_initially_zero)
#     278     return res if res is not None else dag
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:382, in _synthesize_op_using_plugins(operation, input_qubits, data, tracker)
#     378 plugin_args["num_dirty_ancillas"] = num_dirty_ancillas
#     380 qubits = input_qubits if data.use_physical_indices else None
# --> 382 decomposition = plugin_method.run(
#     383     operation,
#     384     coupling_map=data.coupling_map,
#     385     target=data.target,
#     386     qubits=qubits,
#     387     **plugin_args,
#     388 )
#     390 # The synthesis methods that are not suited for the given higher-level-object
#     391 # will return None.
#     392 if decomposition is not None:
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passes/synthesis/hls_plugins.py:1474, in MCMTSynthesisDefault.run(self, high_level_object, coupling_map, target, qubits, **options)
#    1467 if (
#    1468     decomposition := MCMTSynthesisVChain().run(
#    1469         high_level_object, coupling_map, target, qubits, **options
#    1470     )
#    1471 ) is not None:
#    1472     return decomposition
# -> 1474 return MCMTSynthesisNoAux().run(high_level_object, coupling_map, target, qubits, **options)
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passes/synthesis/hls_plugins.py:1502, in MCMTSynthesisNoAux.run(self, high_level_object, coupling_map, target, qubits, **options)
#    1498         base.append(base_gate, [i], [])
#    1500     circuit = base.control(high_level_object.num_ctrl_qubits, ctrl_state=ctrl_state)
# -> 1502 return circuit.decompose()
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:3653, in QuantumCircuit.decompose(self, gates_to_decompose, reps)
#    3651 pass_ = Decompose(gates_to_decompose, apply_synthesis=True)
#    3652 for _ in range(reps):
# -> 3653     dag = pass_.run(dag)
#    3655 # do not copy operations, this is done in the conversion with circuit_to_dag
#    3656 return dag_to_circuit(dag, copy_operations=False)
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/passes/basis/decompose.py:62, in Decompose.run(self, dag)
#      53 """Run the Decompose pass on `dag`.
#      54
#      55 Args:
#    (...)     59     output dag where ``gate`` was expanded.
#      60 """
#      61 # We might use HLS to synthesize objects that do not have a definition
# ---> 62 hls = HighLevelSynthesis(qubits_initially_zero=False) if self.apply_synthesis else None
#      64 # Walk through the DAG and expand each non-basis node
#      65 for node in dag.op_nodes():
#      66     # Check in self.gates_to_decompose if the operation should be decomposed
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/basepasses.py:50, in MetaPass.__call__(cls, *args, **kwargs)
#      48 def __call__(cls, *args, **kwargs):
#      49     pass_instance = type.__call__(cls, *args, **kwargs)
# ---> 50     pass_instance._hash = hash(MetaPass._freeze_init_parameters(cls, args, kwargs))
#      51     return pass_instance
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/site-packages/qiskit/transpiler/basepasses.py:57, in MetaPass._freeze_init_parameters(class_, args, kwargs)
#      55 self_guard = object()
#      56 init_signature = signature(class_.__init__)
# ---> 57 bound_signature = init_signature.bind(self_guard, *args, **kwargs)
#      58 arguments = [("class_.__name__", class_.__name__)]
#      59 for name, value in bound_signature.arguments.items():
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/inspect.py:3295, in Signature.bind(self, *args, **kwargs)
#    3290 def bind(self, /, *args, **kwargs):
#    3291     """Get a BoundArguments object, that maps the passed `args`
#    3292     and `kwargs` to the function's signature.  Raises `TypeError`
#    3293     if the passed arguments can not be bound.
#    3294     """
# -> 3295     return self._bind(args, kwargs)
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/inspect.py:3262, in Signature._bind(self, args, kwargs, partial)
#    3255     arg_val = kwargs.pop(param_name)
#    3256 except KeyError:
#    3257     # We have no value for this parameter.  It's fine though,
#    3258     # if it has a default value, or it is an '*args'-like
#    3259     # parameter, left alone by the processing of positional
#    3260     # arguments.
#    3261     if (not partial and param.kind != _VAR_POSITIONAL and
# -> 3262                                         param.default is _empty):
#    3263         raise TypeError('missing a required argument: {arg!r}'. \
#    3264                         format(arg=param_name)) from None
#    3266 else:
#
# File /opt/anaconda3/envs/quantum_n_body/lib/python3.13/inspect.py:2811, in Parameter.default(self)
#    2807 @property
#    2808 def name(self):
#    2809     return self._name
# -> 2811 @property
#    2812 def default(self):
#    2813     return self._default
#    2815 @property
#    2816 def annotation(self):
#
# KeyboardInterrupt:

# %% [markdown]
# Printing out updated m and number of successes in first precritical stage

# %%
print("n_success =",n_success)
print("Updated m =",m)
print("n_success/k =",n_success/k)
# Out:
# n_success = 531
# Updated m = 5.9719679999999995
# n_success/k = 0.2562741312741313

# %% [markdown]
# **Second Stage**

# %%
success=False
A=set()

while not success:
    n_success=0
    k=6*alpha*math.log(n)
    d=0
    while n_success<=k:
        j=random.randint(1,math.ceil(m)-1)
        qc=grover.create_grover_circuit(iterations=j)
        result=grover.run(qc)
        
        if result in marked_states:
            n_success+=1
            if result not in A:
                A.add(result)
                d+=1
    if d/k<0.5:
        success=True
    
u=4*len(A)

# %% [markdown]
# **Third Stage**

# %%
n_success=0
k=(alpha+1)*u*math.log(n)
while n_success<=k:
    j=random.randint(1,math.ceil(m)-1)
    qc=grover.create_grover_circuit(iterations=j)
    result=grover.run(qc)
    if result in marked_states:
            n_success+=1
            if result not in A:
                A.add(result)
print(A)
# Out:
# {'0011001111010', '0111011101000', '0111010101101', '1110101101000', '1001011000110', '0011110000110', '1111111101000', '1100110010111', '1111100001110', '0111000110101', '0001010010101', '1110001101100', '1000100010111', '1001011000010', '0100101101100', '0010100101010', '0000100011011', '1010011000010', '0000110100101', '1000100101100', '1001011001010', '0101010011001', '1011001011110', '1010100000001', '1010010111100', '0011101011100', '1011011010010', '0101000101111', '1101001001010', '0010011010000', '0001110001001', '1001001000101', '1111000010110', '0001001100000', '0111010111001', '0110101111001', '1011110010000', '1101001001000', '0010001101100', '0010101011001', '0101101101111', '0101100000010', '1000001110101', '0101100101001', '1100010110000', '0001010111101', '1110100011001', '1101010010011', '1011011010110', '1101111101111'}

# %% [markdown]
# **Success Determination**

# %%
matching = 0
for i in A:
    if i in marked_states:
        matching+=1
    
achieved_success_rate=matching/len(marked_states)
print(f"Achieved Success Rate: {achieved_success_rate*100}%")
# Out:
# Achieved Success Rate: 100.0%

# %%
print(len(marked_states))
# Out:
# 50
